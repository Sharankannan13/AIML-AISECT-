# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv('/content/Project 1 - Weather Dataset.csv')

# %%
dataset
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
dataset=dataset.drop(["Date/Time"],axis = 1)

# %%
dataset
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa               Weather
# 0        101.24                   Fog
# ...

# %%
dataset=dataset.drop(["Dew Point Temp_C"],axis = 1)

# %%
dataset
# Out:
#       Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  \
# 0       -1.8         86                4            8.0     101.24
# 1       -1.8         87                4            8.0     101.24
# 2       -1.8         89                7            4.0     101.26
# 3       -1.5         88                6            4.0     101.27
# 4       -1.5         88                7            4.8     101.23
# ...      ...        ...              ...            ...        ...
# 8779     0.1         81               30            9.7     100.13
# 8780     0.2         83               24            9.7     100.03
# 8781    -0.5         93               28            4.8      99.95
# 8782    -0.2         89               28            9.7      99.91
# 8783     0.0         86               30           11.3      99.89
#
#                    Weather
# 0                      Fog
# 1                      Fog
# 2     Freezing Drizzle,Fog
# 3     Freezing Drizzle,Fog
# ...

# %%
def map_weather_keywords(w):
    w = w.lower()
    if 'clear' in w:
        return 'Clear'
    elif 'cloudy' in w:
        return 'Cloudy'
    elif 'rain' in w or 'drizzle' in w or 'shower' in w:
        return 'Rain'
    elif 'snow' in w or 'pellet' in w:
        return 'Snow'
    elif 'fog' in w or 'haze' in w:
        return 'Fog/Mist/Haze'
    elif 'thunder' in w:
        return 'Thunderstorm'
    elif 'freezing' in w or 'ice' in w:
        return 'Ice/Freezing'
    else:
        return 'Other'

dataset['Weather_Category'] = dataset['Weather'].apply(map_weather_keywords)
display(dataset['Weather_Category'].value_counts())
# Out:
# Weather_Category
# Cloudy           3797
# Clear            3432
# Rain              919
# Snow              464
# Fog/Mist/Haze     170
# Thunderstorm        2
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Temp_C', 'Rel Hum_%', 'Wind Speed_km/h', 'Visibility_km', 'Press_kPa',
#        'Weather', 'Weather_Category'],
#       dtype='object')

# %%
dataset=dataset.drop(["Weather"],axis = 1)

# %%
X = dataset[['Temp_C', 'Rel Hum_%', 'Wind Speed_km/h', 'Visibility_km', 'Press_kPa']]
Y = dataset['Weather_Category']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.33, random_state=42)

# %%
X
# Out:
#       Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa
# 0       -1.8         86                4            8.0     101.24
# 1       -1.8         87                4            8.0     101.24
# 2       -1.8         89                7            4.0     101.26
# 3       -1.5         88                6            4.0     101.27
# 4       -1.5         88                7            4.8     101.23
# ...      ...        ...              ...            ...        ...
# 8779     0.1         81               30            9.7     100.13
# 8780     0.2         83               24            9.7     100.03
# 8781    -0.5         93               28            4.8      99.95
# 8782    -0.2         89               28            9.7      99.91
# 8783     0.0         86               30           11.3      99.89
#
# [8784 rows x 5 columns]

# %%
Y
# Out:
# 0       Fog/Mist/Haze
# 1       Fog/Mist/Haze
# 2                Rain
# 3                Rain
# 4       Fog/Mist/Haze
#             ...
# 8779             Snow
# 8780             Snow
# 8781             Snow
# 8782             Snow
# 8783             Snow
# Name: Weather_Category, Length: 8784, dtype: object

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
X_train
# Out:
#       Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa
# 6987     8.9         78                9           25.0     100.91
# 2363     9.4         40               15           48.3     100.46
# 5020    17.6         70               13           25.0     101.14
# 6659    13.3         97                6            6.4     101.47
# 1161    -0.6         70               24           48.3     100.85
# ...      ...        ...              ...            ...        ...
# 5734    23.9         65               15           25.0     101.52
# 5191    21.8         67               17           48.3     101.75
# 5390    26.4         56               13           48.3     100.62
# 860     -2.8         67               24           25.0     101.25
# 7270    14.2         75               50           25.0      99.37
#
# [5885 rows x 5 columns]

# %%
y_train
# Out:
# 6987           Cloudy
# 2363           Cloudy
# 5020           Cloudy
# 6659    Fog/Mist/Haze
# 1161            Clear
#             ...
# 5734           Cloudy
# 5191            Clear
# 5390            Clear
# 860            Cloudy
# 7270           Cloudy
# Name: Weather_Category, Length: 5885, dtype: object

# %%
from sklearn.metrics import classification_report

# %%
cls=classification_report(y_test, y_pred)

# %%
print(cls)
# Out:
#                precision    recall  f1-score   support
#
#         Clear       0.65      0.66      0.65      1122
#        Cloudy       0.63      0.65      0.64      1263
# Fog/Mist/Haze       0.65      0.68      0.67        53
#          Rain       0.56      0.51      0.53       298
#          Snow       0.68      0.66      0.67       163
#
#      accuracy                           0.64      2899
#     macro avg       0.64      0.63      0.63      2899
#  weighted avg       0.64      0.64      0.64      2899

# %%
dataset['Weather_Category'].value_counts()
# Out:
# Weather_Category
# Cloudy           3797
# Clear            3432
# Rain              919
# Snow              464
# Fog/Mist/Haze     170
# Thunderstorm        2
# Name: count, dtype: int64

# %%
print(cls)
# Out:
#                precision    recall  f1-score   support
#
#         Clear       0.65      0.66      0.65      1122
#        Cloudy       0.63      0.65      0.64      1263
# Fog/Mist/Haze       0.65      0.68      0.67        53
#          Rain       0.56      0.51      0.53       298
#          Snow       0.68      0.66      0.67       163
#
#      accuracy                           0.64      2899
#     macro avg       0.64      0.63      0.63      2899
#  weighted avg       0.64      0.64      0.64      2899

# %%
#summary for the classification report
#          precision    recall  f1-score   support

Clear         0.65      0.66      0.66      1122
Cloudy        0.64      0.64      0.64      1263
Fog/Mist/Haze 0.60      0.66      0.63        53
Rain          0.55      0.50      0.52       298
Snow          0.66      0.64      0.65       163
Thunderstorm  0.00      0.00      0.00         0
#here all the outputs of the dataset has high so i compress and list out all the values in the six columns such as Clear,
#Cloudy,Fog/Mist/Haze, Rain, Snow, Thunderstorm .
#clear- 65 percent was correctly predicted as a clear weather and 66 percent incorrectly predicted as not clear.
#Cloudy-64 percent was correctly predicteed as a cloudy weather and 64 percent incorrectly predicted as not cloudy.
#Fog/Mist/Haze-60 percent was correctly predicteed as a Fog/Mist/Haze and 66percent incorrectly predicted as not Fog/Mist/Haze.
#Rain-55 percent was correctly predicteed as a Rain and 50 percent incorrectly predicted as not Rain.
#Snow-66 percent was correctly predicteed as a Snow and 64 percent incorrectly predicted as not Snow.
#Thunderstorm- precision and recall both are zero.
# Out:
#   File "/tmp/ipython-input-1437879452.py", line 4
#     Clear         0.65      0.66      0.66      1122
#                   ^
# SyntaxError: invalid syntax
