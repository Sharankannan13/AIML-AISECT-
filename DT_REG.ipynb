# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(indep)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
# ------------------ Decision Tree Regressor ------------------
param_grid = {
    'criterion': ['squared_error', 'absolute_error'],   # loss functions
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid = GridSearchCV(
    estimator=DecisionTreeRegressor(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

# fitting the model for grid search
grid.fit(X,dep)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 5, 10, 20],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='r2')

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'criterion': 'absolute_error', 'max_depth': 5, 'min_samples_split': 2}
# r2: 0.8436700096396649

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.053324      0.011328         0.004674        0.002552
# 16       0.046193      0.014216         0.002996        0.000467
# 17       0.060250      0.001514         0.006144        0.002360
# 5        0.008951      0.005097         0.006073        0.004550
# 4        0.008578      0.004408         0.005272        0.003877
# 3        0.008059      0.003731         0.006014        0.003730
# 20       0.064954      0.021235         0.006439        0.002865
# 14       0.077499      0.009870         0.002884        0.000281
# 23       0.042183      0.005583         0.002930        0.000727
# 8        0.010812      0.003786         0.004477        0.003252
# 11       0.012079      0.004522         0.007305        0.005910
# 2        0.011197      0.008742         0.003134        0.000881
# 19       0.067125      0.021000         0.004760        0.002712
# 7        0.007358      0.000437         0.002699        0.000158
# 18       0.061576      0.016526         0.004465        0.001726
# 13       0.079853      0.014087         0.004036        0.001996
# 22       0.055583      0.015044         0.004971        0.004366
# 10       0.015890      0.003526         0.004760        0.002585
# 1        0.013923      0.004351         0.003971        0.002250
# 6        0.012761      0.001394         0.007172        0.003357
# 21       0.055118      0.013885         0.004310        0.003076
# 0        0.015218      0.007619         0.004709        0.002555
# 12       0.086806      0.005221         0.011791        0.002480
# 9        0.014007      0.007189         0.002672        0.000245
#
#    param_criterion param_max_depth  param_min_samples_split  \
# 15  absolute_error               5                        2
# 16  absolute_error               5                        5
# 17  absolute_error               5                       10
# 5    squared_error               5                       10
# 4    squared_error               5                        5
# 3    squared_error               5                        2
# 20  absolute_error              10                       10
# 14  absolute_error            None                       10
# 23  absolute_error              20                       10
# 8    squared_error              10                       10
# 11   squared_error              20                       10
# 2    squared_error            None                       10
# 19  absolute_error              10                        5
# 7    squared_error              10                        5
# 18  absolute_error              10                        2
# 13  absolute_error            None                        5
# 22  absolute_error              20                        5
# 10   squared_error              20                        5
# 1    squared_error            None                        5
# 6    squared_error              10                        2
# 21  absolute_error              20                        2
# 0    squared_error            None                        2
# 12  absolute_error            None                        2
# 9    squared_error              20                        2
#
#                                                params  split0_test_score  \
# 15  {'criterion': 'absolute_error', 'max_depth': 5...           0.885227
# 16  {'criterion': 'absolute_error', 'max_depth': 5...           0.885227
# 17  {'criterion': 'absolute_error', 'max_depth': 5...           0.885227
# 5   {'criterion': 'squared_error', 'max_depth': 5,...           0.871005
# 4   {'criterion': 'squared_error', 'max_depth': 5,...           0.871005
# 3   {'criterion': 'squared_error', 'max_depth': 5,...           0.871181
# 20  {'criterion': 'absolute_error', 'max_depth': 1...           0.827812
# 14  {'criterion': 'absolute_error', 'max_depth': N...           0.821727
# 23  {'criterion': 'absolute_error', 'max_depth': 2...           0.821727
# 8   {'criterion': 'squared_error', 'max_depth': 10...           0.834786
# 11  {'criterion': 'squared_error', 'max_depth': 20...           0.831445
# 2   {'criterion': 'squared_error', 'max_depth': No...           0.831445
# 19  {'criterion': 'absolute_error', 'max_depth': 1...           0.779607
# 7   {'criterion': 'squared_error', 'max_depth': 10...           0.779396
# 18  {'criterion': 'absolute_error', 'max_depth': 1...           0.774016
# 13  {'criterion': 'absolute_error', 'max_depth': N...           0.754507
# 22  {'criterion': 'absolute_error', 'max_depth': 2...           0.754507
# 10  {'criterion': 'squared_error', 'max_depth': 20...           0.757309
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.757309
# 6   {'criterion': 'squared_error', 'max_depth': 10...           0.766964
# 21  {'criterion': 'absolute_error', 'max_depth': 2...           0.751794
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.735914
# 12  {'criterion': 'absolute_error', 'max_depth': N...           0.752414
# 9   {'criterion': 'squared_error', 'max_depth': 20...           0.735894
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 15           0.781353           0.881422           0.820743
# 16           0.781353           0.881422           0.820743
# 17           0.781353           0.881422           0.820743
# 5            0.779829           0.874556           0.822363
# 4            0.779807           0.874556           0.822363
# 3            0.779807           0.874556           0.822363
# 20           0.749391           0.832392           0.793159
# 14           0.749612           0.825741           0.793135
# 23           0.749612           0.825741           0.793135
# 8            0.728910           0.817145           0.779657
# 11           0.726459           0.812354           0.779250
# 2            0.726459           0.812354           0.779250
# 19           0.729409           0.794357           0.776815
# 7            0.702334           0.803198           0.754059
# 18           0.719611           0.780798           0.767744
# 13           0.656693           0.786129           0.764103
# 22           0.656693           0.786129           0.764103
# 10           0.695819           0.768677           0.745213
# 1            0.695819           0.768638           0.745213
# 6            0.673109           0.767733           0.718142
# 21           0.589107           0.715720           0.728531
# 0            0.646517           0.731020           0.748060
# 12           0.584181           0.715721           0.728531
# 9            0.652098           0.719619           0.748060
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 15           0.849605         0.843670        0.038978                1
# 16           0.849605         0.843670        0.038978                1
# 17           0.849605         0.843670        0.038978                1
# 5            0.861384         0.841827        0.036132                4
# 4            0.861384         0.841823        0.036139                5
# 3            0.861057         0.841793        0.036133                6
# 20           0.818179         0.804187        0.030573                7
# 14           0.818183         0.801679        0.028416                8
# 23           0.818183         0.801679        0.028416                8
# 8            0.814617         0.795023        0.037581               10
# 11           0.794723         0.788846        0.035738               11
# 2            0.794723         0.788846        0.035738               11
# 19           0.797660         0.775569        0.024453               13
# 7            0.800444         0.767886        0.037223               14
# 18           0.782817         0.764997        0.023307               15
# 13           0.794539         0.751194        0.049411               16
# 22           0.794539         0.751194        0.049411               16
# 10           0.767426         0.746889        0.026892               18
# 1            0.767426         0.746881        0.026886               19
# 6            0.771707         0.739531        0.038607               20
# 21           0.766320         0.710294        0.063102               21
# 0            0.688427         0.709988        0.037570               22
# 12           0.748261         0.705821        0.062261               23
# 9            0.672204         0.705575        0.037134               24

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
