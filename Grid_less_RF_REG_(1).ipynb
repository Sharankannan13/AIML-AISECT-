# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(indep)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
# ------------------ Random Forest Regressor ------------------
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'criterion': ['squared_error', 'absolute_error']
}

grid = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)
# fitting the model for grid search
grid.fit(X,dep)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 10, 20],
#                          'n_estimators': [50, 100, 200]},
#              scoring='r2')

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'criterion': 'absolute_error', 'max_depth': 10, 'n_estimators': 200}
# r2: 0.8385494280708284

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 14       5.292560      0.547177         0.041974        0.001481
# 13       2.365630      0.038493         0.023094        0.001793
# 12       1.504140      0.362993         0.013215        0.001590
# 5        1.045632      0.124172         0.048361        0.006032
# 4        0.502107      0.016913         0.028321        0.005509
# 3        0.250855      0.013996         0.012776        0.000172
# 2        1.514950      0.423118         0.055533        0.016692
# 8        1.656570      0.281081         0.083365        0.025741
# 7        0.591859      0.012872         0.029770        0.006187
# 1        0.750810      0.179761         0.029457        0.008244
# 6        0.547671      0.080357         0.030289        0.013509
# 0        0.297443      0.008655         0.017036        0.004500
# 16       2.934761      0.518483         0.023930        0.000287
# 10       2.626150      0.250713         0.030619        0.013017
# 17       5.325640      0.868577         0.057288        0.021957
# 11       5.655189      0.557688         0.047652        0.002714
# 15       1.352358      0.152455         0.016188        0.005851
# 9        1.256818      0.009183         0.013329        0.000136
#
#    param_criterion param_max_depth  param_n_estimators  \
# 14  absolute_error              10                 200
# 13  absolute_error              10                 100
# 12  absolute_error              10                  50
# 5    squared_error              10                 200
# 4    squared_error              10                 100
# 3    squared_error              10                  50
# 2    squared_error            None                 200
# 8    squared_error              20                 200
# 7    squared_error              20                 100
# 1    squared_error            None                 100
# 6    squared_error              20                  50
# 0    squared_error            None                  50
# 16  absolute_error              20                 100
# 10  absolute_error            None                 100
# 17  absolute_error              20                 200
# 11  absolute_error            None                 200
# 15  absolute_error              20                  50
# 9   absolute_error            None                  50
#
#                                                params  split0_test_score  \
# 14  {'criterion': 'absolute_error', 'max_depth': 1...           0.858386
# 13  {'criterion': 'absolute_error', 'max_depth': 1...           0.859199
# 12  {'criterion': 'absolute_error', 'max_depth': 1...           0.859859
# 5   {'criterion': 'squared_error', 'max_depth': 10...           0.857744
# 4   {'criterion': 'squared_error', 'max_depth': 10...           0.857371
# 3   {'criterion': 'squared_error', 'max_depth': 10...           0.854350
# 2   {'criterion': 'squared_error', 'max_depth': No...           0.849735
# 8   {'criterion': 'squared_error', 'max_depth': 20...           0.849880
# 7   {'criterion': 'squared_error', 'max_depth': 20...           0.851029
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.850836
# 6   {'criterion': 'squared_error', 'max_depth': 20...           0.848781
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.848172
# 16  {'criterion': 'absolute_error', 'max_depth': 2...           0.841942
# 10  {'criterion': 'absolute_error', 'max_depth': N...           0.841920
# 17  {'criterion': 'absolute_error', 'max_depth': 2...           0.839410
# 11  {'criterion': 'absolute_error', 'max_depth': N...           0.839365
# 15  {'criterion': 'absolute_error', 'max_depth': 2...           0.841199
# 9   {'criterion': 'absolute_error', 'max_depth': N...           0.841199
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 14           0.785587           0.864403           0.834324
# 13           0.785846           0.864747           0.833908
# 12           0.783662           0.861211           0.834315
# 5            0.775167           0.865729           0.822606
# 4            0.775041           0.864765           0.820739
# 3            0.772485           0.862323           0.822612
# 2            0.770294           0.856616           0.819745
# 8            0.770319           0.856770           0.819712
# 7            0.769061           0.855619           0.818332
# 1            0.768926           0.855465           0.818257
# 6            0.766130           0.852838           0.821488
# 0            0.765825           0.852530           0.821471
# 16           0.767939           0.848735           0.822628
# 10           0.768017           0.848133           0.822628
# 17           0.768584           0.848036           0.823860
# 11           0.768649           0.847868           0.823894
# 15           0.763773           0.846123           0.824536
# 9            0.763596           0.845759           0.824536
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 14           0.850047         0.838549        0.028344                1
# 13           0.848513         0.838443        0.028323                2
# 12           0.846044         0.837018        0.028435                3
# 5            0.844893         0.833228        0.032488                4
# 4            0.843892         0.832362        0.032339                5
# 3            0.839614         0.830277        0.031913                6
# 2            0.839630         0.827204        0.031053                7
# 8            0.839310         0.827198        0.031071                8
# 7            0.838412         0.826490        0.031488                9
# 1            0.838723         0.826442        0.031506               10
# 6            0.834776         0.824802        0.031349               11
# 0            0.835109         0.824621        0.031338               12
# 16           0.836597         0.823568        0.029107               13
# 10           0.836640         0.823468        0.028975               14
# 17           0.837093         0.823397        0.028481               15
# 11           0.837081         0.823371        0.028421               16
# 15           0.833649         0.821856        0.029943               17
# 9            0.833734         0.821765        0.029960               18

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))
